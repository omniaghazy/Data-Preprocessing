# %% [markdown]
# <a href="https://colab.research.google.com/github/omniaghazy/Data-Preprocessing/blob/main/IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd .read_csv("/content/Iris.csv")

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = df.drop(columns = ['Id'])

# %%
df.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
fig = df[df.Species=='Iris-setosa'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='orange', label='Setosa')
df[df.Species=='Iris-versicolor'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='blue', label='versicolor',ax=fig)
df[df.Species=='Iris-virginica'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='green', label='virginica', ax=fig)

fig.set_xlabel("Sepal Length")
fig.set_ylabel("Sepal Width")
fig.set_title("Sepal Length VS Width")
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %%
fig = df[df.Species=='Iris-setosa'].plot.scatter(x='PetalLengthCm',y='Species',color='orange', label='Setosa')
df[df.Species=='Iris-versicolor'].plot.scatter(x='PetalLengthCm',y='Species',color='blue', label='versicolor',ax=fig)
df[df.Species=='Iris-virginica'].plot.scatter(x='PetalLengthCm',y='Species',color='green', label='virginica', ax=fig)
fig.set_xlabel("Petal Length")
# fig.set_ylabel("Petal Width")
# fig.set_title(" Petal Length VS Width")
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %%
fig = df[df.Species=='Iris-setosa'].plot.scatter(x='PetalWidthCm',y='Species',color='orange', label='Setosa')
df[df.Species=='Iris-versicolor'].plot.scatter(x='PetalWidthCm',y='Species',color='blue', label='versicolor',ax=fig)
df[df.Species=='Iris-virginica'].plot.scatter(x='PetalWidthCm',y='Species',color='green', label='virginica', ax=fig)
fig.set_xlabel("Petal Width")
# fig.set_ylabel("Petal Width")
# fig.set_title(" Petal Length VS Width")
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %%
fig = df[df.Species=='Iris-setosa'].plot.scatter(x='SepalLengthCm',y='Species',color='orange', label='Setosa')
df[df.Species=='Iris-versicolor'].plot.scatter(x='SepalLengthCm',y='Species',color='blue', label='versicolor',ax=fig)
df[df.Species=='Iris-virginica'].plot.scatter(x='SepalLengthCm',y='Species',color='green', label='virginica', ax=fig)
fig.set_xlabel("Sepal LengthCm")
# fig.set_ylabel("Petal Width")
# fig.set_title(" Petal Length VS Width")
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %%
fig = df[df.Species=='Iris-setosa'].plot.scatter(x='SepalWidthCm',y='Species',color='orange', label='Setosa')
df[df.Species=='Iris-versicolor'].plot.scatter(x='SepalWidthCm',y='Species',color='blue', label='versicolor',ax=fig)
df[df.Species=='Iris-virginica'].plot.scatter(x='SepalWidthCm',y='Species',color='green', label='virginica', ax=fig)
fig.set_xlabel("Sepal widthCm")

fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %%
fig = df[df.Species=='Iris-setosa'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='orange', label='Setosa')
df[df.Species=='Iris-versicolor'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='blue', label='versicolor',ax=fig)
df[df.Species=='Iris-virginica'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='green', label='virginica', ax=fig)
fig.set_xlabel("Petal Length")
fig.set_ylabel("Petal Width")
fig.set_title(" Petal Length VS Width")
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %%
df.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(411)
plt.title("Sepal Length")
sns.boxplot(y="SepalLengthCm", x="Species", data=df)
plt.subplot(412)
plt.title("Sepal Width")
sns.boxplot(y="SepalWidthCm", x="Species", data=df)
plt.subplot(413)
plt.title("Petal Length")
sns.boxplot(y="PetalLengthCm", x="Species", data=df)
plt.subplot(414)
plt.title("Petal Width")
sns.boxplot(y="PetalWidthCm", x="Species", data=df)
plt.tight_layout()

# %%
sns.pairplot(df, hue='Species')

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=df)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=df)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=df)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Species'] = label_encoder.fit_transform(df['Species'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
x = df[df.drop(columns=['Species']).columns]
y = df[['Species']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train.values.ravel())

y_pred = knn.predict(x_test)
print(f"Accuracy: {knn.score(x_test,y_test)}")
print(f"Accuracy: {knn.score(x_train,y_train)}")
# Out:
# Accuracy: 0.9333333333333333
# Accuracy: 0.9658119658119658

# %%
from sklearn.metrics import  classification_report
print("classification report :" , classification_report(y_test,y_pred))
# Out:
# classification report :               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.90      0.90      0.90        10
#            2       0.89      0.89      0.89         9
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

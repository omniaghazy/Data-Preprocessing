# %% [markdown]
# <a href="https://colab.research.google.com/github/omniaghazy/Data-Preprocessing/blob/main/WAZE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/waze_dataset.csv')

# %%
df.shape
# Out:
# (14999, 13)

# %%
df.describe()
# Out:
#                  ID      sessions        drives  total_sessions  \
# count  14999.000000  14999.000000  14999.000000    14999.000000
# mean    7499.000000     80.633776     67.281152      189.964447
# std     4329.982679     80.699065     65.913872      136.405128
# min        0.000000      0.000000      0.000000        0.220211
# 25%     3749.500000     23.000000     20.000000       90.661156
# 50%     7499.000000     56.000000     48.000000      159.568115
# 75%    11248.500000    112.000000     93.000000      254.192341
# max    14998.000000    743.000000    596.000000     1216.154633
#
#        n_days_after_onboarding  total_navigations_fav1  \
# count             14999.000000            14999.000000
# mean               1749.837789              121.605974
# std                1008.513876              148.121544
# min                   4.000000                0.000000
# 25%                 878.000000                9.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       14999 non-null  int64
#  1   label                    14299 non-null  object
#  2   sessions                 14999 non-null  int64
#  3   drives                   14999 non-null  int64
#  4   total_sessions           14999 non-null  float64
#  5   n_days_after_onboarding  14999 non-null  int64
#  6   total_navigations_fav1   14999 non-null  int64
#  7   total_navigations_fav2   14999 non-null  int64
#  8   driven_km_drives         14999 non-null  float64
#  9   duration_minutes_drives  14999 non-null  float64
#  10  activity_days            14999 non-null  int64
#  11  driving_days             14999 non-null  int64
#  12  device                   14999 non-null  object
# dtypes: float64(3), int64(8), object(2)
# memory usage: 1.5+ MB

# %%
df.head(20
        )
# Out:
#     ID     label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0    0  retained       283     226      296.748273                     2276
# 1    1  retained       133     107      326.896596                     1225
# 2    2  retained       114      95      135.522926                     2651
# 3    3  retained        49      40       67.589221                       15
# 4    4  retained        84      68      168.247020                     1562
# 5    5  retained       113     103      279.544437                     2637
# 6    6  retained         3       2      236.725314                      360
# 7    7  retained        39      35      176.072845                     2999
# 8    8  retained        57      46      183.532018                      424
# 9    9   churned        84      68      244.802115                     2997
# 10  10  retained        23      20      117.225772                     1946
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.isna().sum()
# Out:
# ID                           0
# label                      700
# sessions                     0
# drives                       0
# total_sessions               0
# n_days_after_onboarding      0
# total_navigations_fav1       0
# total_navigations_fav2       0
# driven_km_drives             0
# duration_minutes_drives      0
# activity_days                0
# driving_days                 0
# device                       0
# dtype: int64

# %%
df.drop(  'ID', axis=1, inplace=True)

# %%
df.head(10)
# Out:
#       label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0  retained       283     226      296.748273                     2276
# 1  retained       133     107      326.896596                     1225
# 2  retained       114      95      135.522926                     2651
# 3  retained        49      40       67.589221                       15
# 4  retained        84      68      168.247020                     1562
# 5  retained       113     103      279.544437                     2637
# 6  retained         3       2      236.725314                      360
# 7  retained        39      35      176.072845                     2999
# 8  retained        57      46      183.532018                      424
# 9   churned        84      68      244.802115                     2997
#
#    total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# 0                     208                       0       2628.845068
# ...

# %%
df["km/min"] = df["driven_km_drives"] / df["duration_minutes_drives"]

# %%
df
# Out:
#           label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0      retained       283     226      296.748273                     2276
# 1      retained       133     107      326.896596                     1225
# 2      retained       114      95      135.522926                     2651
# 3      retained        49      40       67.589221                       15
# 4      retained        84      68      168.247020                     1562
# ...         ...       ...     ...             ...                      ...
# 14994  retained        60      55      207.875622                      140
# 14995  retained        42      35      187.670313                     2505
# 14996  retained       273     219      422.017241                     1873
# 14997   churned       149     120      180.524184                     3150
# 14998  retained        73      58      353.419797                     3383
#
# ...

# %%
df.columns
# Out:
# Index(['label', 'sessions', 'drives', 'total_sessions',
#        'n_days_after_onboarding', 'total_navigations_fav1',
#        'total_navigations_fav2', 'driven_km_drives', 'duration_minutes_drives',
#        'activity_days', 'driving_days', 'device', 'km/min'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x="activity_days", y="sessions")
# Out:
# <Axes: xlabel='activity_days', ylabel='sessions'>

# %%
# df["session/ACTday"] = df["sessions"] / df["activity_days"]
# df["session/ACTday"].max()

# %%
df
# Out:
#           label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0      retained       283     226      296.748273                     2276
# 1      retained       133     107      326.896596                     1225
# 2      retained       114      95      135.522926                     2651
# 3      retained        49      40       67.589221                       15
# 4      retained        84      68      168.247020                     1562
# ...         ...       ...     ...             ...                      ...
# 14994  retained        60      55      207.875622                      140
# 14995  retained        42      35      187.670313                     2505
# 14996  retained       273     219      422.017241                     1873
# 14997   churned       149     120      180.524184                     3150
# 14998  retained        73      58      353.419797                     3383
#
# ...

# %%
sns.scatterplot(data=df, x="activity_days", y="driving_days")
# Out:
# <Axes: xlabel='activity_days', ylabel='driving_days'>

# %%
# df["favNavig/ACTday"] = df["nav_fav_count_drives"] / df["activity_days"]
# df["favNavig/ACTday"].max()

# %%
categorical_columns = df[df.select_dtypes(include='object').columns]
categorical_columns
# Out:
#           label   device
# 0      retained  Android
# 1      retained   iPhone
# 2      retained  Android
# 3      retained   iPhone
# 4      retained  Android
# ...         ...      ...
# 14994  retained   iPhone
# 14995  retained  Android
# 14996  retained   iPhone
# 14997   churned   iPhone
# 14998  retained   iPhone
#
# [14999 rows x 2 columns]

# %%
categorical_columns.groupby('label')["device"].value_counts(normalize = True)
# Out:
# label     device
# churned   iPhone     0.648659
#           Android    0.351341
# retained  iPhone     0.644393
#           Android    0.355607
# Name: proportion, dtype: float64

# %%
for col in categorical_columns:
    print(col)
    print(df[col].value_counts())
    print()
# Out:
# label
# label
# retained    11763
# churned      2536
# Name: count, dtype: int64
#
# device
# device
# iPhone     9672
# Android    5327
# Name: count, dtype: int64

# %%
numerical_columns = df[df.select_dtypes(include='number').columns]
numerical_columns
# Out:
#        sessions  drives  total_sessions  n_days_after_onboarding  \
# 0           283     226      296.748273                     2276
# 1           133     107      326.896596                     1225
# 2           114      95      135.522926                     2651
# 3            49      40       67.589221                       15
# 4            84      68      168.247020                     1562
# ...         ...     ...             ...                      ...
# 14994        60      55      207.875622                      140
# 14995        42      35      187.670313                     2505
# 14996       273     219      422.017241                     1873
# 14997       149     120      180.524184                     3150
# 14998        73      58      353.419797                     3383
#
#        total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# 0                         208                       0       2628.845068
# ...

# %%
numerical_columns.describe()
# Out:
#            sessions        drives  total_sessions  n_days_after_onboarding  \
# count  14999.000000  14999.000000    14999.000000             14999.000000
# mean      80.633776     67.281152      189.964447              1749.837789
# std       80.699065     65.913872      136.405128              1008.513876
# min        0.000000      0.000000        0.220211                 4.000000
# 25%       23.000000     20.000000       90.661156               878.000000
# 50%       56.000000     48.000000      159.568115              1741.000000
# 75%      112.000000     93.000000      254.192341              2623.500000
# max      743.000000    596.000000     1216.154633              3500.000000
#
#        total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# count            14999.000000            14999.000000      14999.000000
# mean               121.605974               29.672512       4039.340921
# std                148.121544               45.394651       2502.149334
# ...

# %%
for col in numerical_columns:
    print(col)
    print(df[col].nunique())
# Out:
# sessions
# 469
# drives
# 401
# total_sessions
# 14999
# n_days_after_onboarding
# 3441
# total_navigations_fav1
# 730
# total_navigations_fav2
# 287
# driven_km_drives
# 14999
# duration_minutes_drives
# 14999
# activity_days
# 32
# driving_days
# 31
# km/min
# 14999

# %%
df.shape
# Out:
# (14999, 13)

# %%
numerical_columns.head()
# Out:
#    sessions  drives  total_sessions  n_days_after_onboarding  \
# 0       283     226      296.748273                     2276
# 1       133     107      326.896596                     1225
# 2       114      95      135.522926                     2651
# 3        49      40       67.589221                       15
# 4        84      68      168.247020                     1562
#
#    total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# 0                     208                       0       2628.845068
# 1                      19                      64      13715.920550
# 2                       0                       0       3059.148818
# 3                     322                       7        913.591123
# 4                     166                       5       3950.202008
#
#    duration_minutes_drives  activity_days  driving_days    km/min
# 0              1985.775061             28            19  1.323838
# ...

# %%
for col in numerical_columns:
    print(col)
    print(f"min ={df[col].min()} ====> max= {df[col].max()}")
    print()
# Out:
# sessions
# min =0 ====> max= 743
#
# drives
# min =0 ====> max= 596
#
# total_sessions
# min =0.2202109438 ====> max= 1216.154633
#
# n_days_after_onboarding
# min =4 ====> max= 3500
#
# total_navigations_fav1
# min =0 ====> max= 1236
#
# total_navigations_fav2
# min =0 ====> max= 415
#
# driven_km_drives
# min =60.44125046 ====> max= 21183.40189
#
# duration_minutes_drives
# min =18.28208247 ====> max= 15851.72716
#
# activity_days
# min =0 ====> max= 31
#
# driving_days
# min =0 ====> max= 30
#
# km/min
# min =1.2002182427313497 ====> max= 394.04868118097306

# %%
for col in numerical_columns:
 sns.histplot(data= numerical_columns , x = col)
 plt.show()

# %%
for col in numerical_columns:
    df[col] = np.log1p(df[col])

# %%
numerical_columns.isna().sum()
# Out:
# sessions                   0
# drives                     0
# total_sessions             0
# n_days_after_onboarding    0
# total_navigations_fav1     0
# total_navigations_fav2     0
# driven_km_drives           0
# duration_minutes_drives    0
# activity_days              0
# driving_days               0
# km/min                     0
# dtype: int64

# %% [markdown]
# session == drives

# %%
numerical_columns.corr()
# Out:
#                          sessions    drives  total_sessions  \
# sessions                 1.000000  0.996822        0.589079
# drives                   0.996822  1.000000        0.586741
# total_sessions           0.589079  0.586741        1.000000
# n_days_after_onboarding  0.005676  0.005216        0.004731
# total_navigations_fav1   0.005713  0.005017        0.002137
# total_navigations_fav2   0.006185  0.007572        0.006421
# driven_km_drives         0.002113  0.001883       -0.000416
# duration_minutes_drives -0.006113 -0.005855       -0.001689
# activity_days            0.024194  0.024043        0.013449
# driving_days             0.018973  0.018847        0.009912
# km/min                   0.009362  0.010179        0.002446
#
#                          n_days_after_onboarding  total_navigations_fav1  \
# sessions                                0.005676                0.005713
# drives                                  0.005216                0.005017
# ...

# %%
df.groupby("label")["sessions"].mean()
# Out:
# label
# churned     3.947246
# retained    3.856794
# Name: sessions, dtype: float64

# %%
df
# Out:
#           label  sessions    drives  total_sessions  n_days_after_onboarding  \
# 0      retained  5.648974  5.424950        5.696248                 7.730614
# 1      retained  4.897840  4.682131        5.792698                 7.111512
# 2      retained  4.744932  4.564348        4.916493                 7.883069
# 3      retained  3.912023  3.713572        4.228135                 2.772589
# 4      retained  4.442651  4.234107        5.131359                 7.354362
# ...         ...       ...       ...             ...                      ...
# 14994  retained  4.110874  4.025352        5.341739                 4.948760
# 14995  retained  3.761200  3.583519        5.240001                 7.826443
# 14996  retained  5.613128  5.393628        6.047413                 7.535830
# 14997   churned  5.010635  4.795791        5.201389                 8.055475
# 14998  retained  4.304065  4.077537        5.870482                 8.126814
#
# ...

# %%
for col in df.select_dtypes(exclude="object"):
  if col != "label":
    print(col)
    print(df.groupby("label")[col].mean())

    sns.boxplot(data=df, x="label", y=col)
    plt.show()
# Out:
# sessions
# label
# churned     3.947246
# retained    3.856794
# Name: sessions, dtype: float64
# drives
# label
# churned     3.796972
# retained    3.707755
# Name: drives, dtype: float64
# total_sessions
# label
# churned     5.022804
# retained    4.970947
# Name: total_sessions, dtype: float64
# n_days_after_onboarding
# label
# churned     6.923487
# retained    7.222911
# Name: n_days_after_onboarding, dtype: float64
# total_navigations_fav1
# label
# churned     3.732612
# retained    3.545174
# Name: total_navigations_fav1, dtype: float64
# total_navigations_fav2
# label
# churned     2.100527
# retained    2.031717
# Name: total_navigations_fav2, dtype: float64
# driven_km_drives
# label
# churned     8.144176
# retained    8.103683
# Name: driven_km_drives, dtype: float64
# duration_minutes_drives
# label
# churned     7.307388
# retained    7.218496
# Name: duration_minutes_drives, dtype: float64
# activity_days
# label
# churned     2.051737
# retained    2.687328
# ...

# %%
for col in numerical_columns:
    if col in ['session/ACTday', 'favNavig/ACTday',""]: # Exclude columns with inf values
        continue
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[col] = np.clip(df[col], lower_bound, upper_bound)

# %%
df['label'].value_counts()
# Out:
# label
# retained    11763
# churned      2536
# Name: count, dtype: int64

# %%
df['label'].isna().sum()
# Out:
# np.int64(700)

# %%
df['label'].value_counts()
# Out:
# label
# retained    11763
# churned      2536
# Name: count, dtype: int64

# %%
# df['label'] = df['label'].fillna("null", inplace=True)

# %%
df
# Out:
#           label  sessions    drives  total_sessions  n_days_after_onboarding  \
# 0      retained  5.648974  5.424950        5.696248                 7.730614
# 1      retained  4.897840  4.682131        5.792698                 7.111512
# 2      retained  4.744932  4.564348        4.916493                 7.883069
# 3      retained  3.912023  3.713572        4.228135                 5.137994
# 4      retained  4.442651  4.234107        5.131359                 7.354362
# ...         ...       ...       ...             ...                      ...
# 14994  retained  4.110874  4.025352        5.341739                 5.137994
# 14995  retained  3.761200  3.583519        5.240001                 7.826443
# 14996  retained  5.613128  5.393628        6.047413                 7.535830
# 14997   churned  5.010635  4.795791        5.201389                 8.055475
# 14998  retained  4.304065  4.077537        5.870482                 8.126814
#
# ...

# %%
df['label'].isna().sum()
# Out:
# np.int64(700)

# %%
# from sklearn.preprocessing import LabelEncoder
# lb = LabelEncoder()
# for col in df.select_dtypes(include="object"):
#   df[col] = lb.fit_transform(df[col])

# %%
df['label'].value_counts()
# Out:
# label
# retained    11763
# churned      2536
# Name: count, dtype: int64

# %%
df['label'].fillna("churned", inplace=True)
# Out:
# /tmp/ipython-input-105941421.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['label'].fillna("churned", inplace=True)

# %%
df['label'].nunique()
# Out:
# 2

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
for col in df.select_dtypes(include="object"):
  df[col] = lb.fit_transform(df[col])

# %%
# from imblearn.over_sampling import SMOTE

# smote=SMOTE(sampling_strategy='minority')
# x,y=smote.fit_resample(df["label"][0],)
# y.value_counts()

# %%
df.isna().sum()
# Out:
# label                      0
# sessions                   0
# drives                     0
# total_sessions             0
# n_days_after_onboarding    0
# total_navigations_fav1     0
# total_navigations_fav2     0
# driven_km_drives           0
# duration_minutes_drives    0
# activity_days              0
# driving_days               0
# device                     0
# km/min                     0
# dtype: int64

# %%
for col in df.columns:
  print(col)
  print(f"min = {df[col].min()} =====> max = {df[col].max()}")
# Out:
# label
# min = 0 =====> max = 1
# sessions
# min = 0.8540528478013534 =====> max = 6.612041034833092
# drives
# min = 0.7963639209035516 =====> max = 6.391917113392602
# total_sessions
# min = 2.9822204270139228 =====> max = 7.0778957999730725
# n_days_after_onboarding
# min = 5.137993750395665 =====> max = 8.160803920954665
# total_navigations_fav1
# min = 0.0 =====> max = 7.1204443723924875
# total_navigations_fav2
# min = 0.0 =====> max = 6.030685260261263
# driven_km_drives
# min = 6.395334776339597 =====> max = 9.880777245916716
# duration_minutes_drives
# min = 5.109407682802382 =====> max = 9.430506083814326
# activity_days
# min = 0.7259806978186303 =====> max = 3.4657359027997265
# driving_days
# min = 0.0 =====> max = 3.4339872044851463
# device
# min = 0 =====> max = 1
# km/min
# min = 0.7885565566856749 =====> max = 2.21741596448212

# %%
df["label"].value_counts()
# Out:
# label
# 1    11763
# 0     3236
# Name: count, dtype: int64

# %%
df["label"].loc[df["label"] == "churned"] = 0
df["label"].loc[df["label"] == "retained"] = 1
# Out:
# /tmp/ipython-input-2012151027.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["label"].loc[df["label"] == "churned"] = 0
# /tmp/ipython-input-2012151027.py:1: SettingWithCopyWarning:
# ...

# %%
y0 = df[df["label"] == 0]
y1 = df[df["label"] == 1]

# %%
# from imblearn.over_sampling import SMOTE

# smote=SMOTE(sampling_strategy='minority')
# x,y=smote.fit_resample(y0,y1)

# %%
x = df.drop("label", axis=1)
y = df["label"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.drop("label", axis=1), df["label"], test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
RF_model=RandomForestClassifier()
RF_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=RF_model.predict(x_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.14      0.22       629
#            1       0.81      0.97      0.88      2371
#
#     accuracy                           0.79      3000
#    macro avg       0.67      0.55      0.55      3000
# weighted avg       0.75      0.79      0.74      3000

# %%
print(confusion_matrix(y_test,y_pred))

# Get the predictions
#
# y_pred = pipeline.predict(X_test)
#
# Calculate the confusion matrix
#
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')

plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
# Out:
# [[  86  543]
#  [  78 2293]]

# %%
from sklearn.metrics import classification_report
from sklearn import metrics

print(classification_report(y_test, y_pred))

accracy = metrics.accuracy_score(y_test, y_pred)
f1_score = metrics.f1_score(y_test, y_pred)
precision = metrics.precision_score(y_test, y_pred)
recall = metrics.recall_score(y_test, y_pred)

print (f'RF_model model Accuracy - : {100*accracy:.3} %')
print (f'RF_model model f1_score - : {100*f1_score:.3} %')
print (f'RF_model model precision - : {100*precision:.3} %')
print (f'RF_model model recall - : {100*recall:.3}  %')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.14      0.22       629
#            1       0.81      0.97      0.88      2371
#
#     accuracy                           0.79      3000
#    macro avg       0.67      0.55      0.55      3000
# weighted avg       0.75      0.79      0.74      3000
#
# RF_model model Accuracy - : 79.3 %
# RF_model model f1_score - : 88.1 %
# RF_model model precision - : 80.9 %
# RF_model model recall - : 96.7  %

# %%
# plot ROC Curve
y_pred1 = RF_model.predict_proba(x_test)[::,1]

# y_pred1 = y_pred1.reshape(-1,1)

from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, y_pred1) # , pos_label = 'Yes'

plt.figure(figsize=(6,4))

plt.plot(fpr, tpr, linewidth=2)

plt.plot([0,1], [0,1], 'k--' )

plt.rcParams['font.size'] = 12

plt.title('ROC curve for RainTomorrow classifier')

plt.xlabel('False Positive Rate (1 - Specificity)')

plt.ylabel('True Positive Rate (Sensitivity)')

plt.show()

# %%
from sklearn.metrics import roc_auc_score

ROC_AUC = roc_auc_score(y_test, y_pred1)

print('ROC AUC : {:.4f}'.format(ROC_AUC))
# Out:
# ROC AUC : 0.6817

# %%
import matplotlib.pyplot as plt
from sklearn import tree

import graphviz
# DOT data
i_tree =0
for tree_in_forest in RF_model.estimators_:

    dot_data = tree.export_graphviz(tree_in_forest, out_file=None,
                                    feature_names=x.columns,
                      #  class_names=['Golf Players'],
                                    filled=True, rounded=True)

    # Draw graph
    graph = graphviz.Source(dot_data, format="png")
    graph



graph.render('RF_model_Tree',format='png', view=True)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.35318 to fit
# 'RF_model_Tree.png'

# %%
features = x.columns
importances = RF_model.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
from xgboost import XGBClassifier

XGB_model=XGBClassifier()
XGB_model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred=XGB_model.predict(x_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.15      0.22       629
#            1       0.81      0.94      0.87      2371
#
#     accuracy                           0.77      3000
#    macro avg       0.60      0.55      0.55      3000
# weighted avg       0.72      0.77      0.73      3000

# %%
print(confusion_matrix(y_test,y_pred))

# Get the predictions
#
# y_pred = pipeline.predict(X_test)
#
# Calculate the confusion matrix
#
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')

plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
# Out:
# [[  97  532]
#  [ 145 2226]]

# %%
from sklearn.metrics import classification_report
from sklearn import metrics

print(classification_report(y_test, y_pred))

accracy = metrics.accuracy_score(y_test, y_pred)
f1_score = metrics.f1_score(y_test, y_pred)
precision = metrics.precision_score(y_test, y_pred)
recall = metrics.recall_score(y_test, y_pred)

print (f'XGB_model model Accuracy - : {100*accracy:.3} %')
print (f'XGB_model model f1_score - : {100*f1_score:.3} %')
print (f'XGB_model model precision - : {100*precision:.3} %')
print (f'XGB_model model recall - : {100*recall:.3}  %')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.15      0.22       629
#            1       0.81      0.94      0.87      2371
#
#     accuracy                           0.77      3000
#    macro avg       0.60      0.55      0.55      3000
# weighted avg       0.72      0.77      0.73      3000
#
# XGB_model model Accuracy - : 77.4 %
# XGB_model model f1_score - : 86.8 %
# XGB_model model precision - : 80.7 %
# XGB_model model recall - : 93.9  %

# %%
# plot ROC Curve
y_pred1 = XGB_model.predict_proba(x_test)[::,1]

# y_pred1 = y_pred1.reshape(-1,1)

from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, y_pred1) # , pos_label = 'Yes'

plt.figure(figsize=(6,4))

plt.plot(fpr, tpr, linewidth=2)

plt.plot([0,1], [0,1], 'k--' )

plt.rcParams['font.size'] = 12

plt.title('ROC curve for RainTomorrow classifier')

plt.xlabel('False Positive Rate (1 - Specificity)')

plt.ylabel('True Positive Rate (Sensitivity)')

plt.show()
